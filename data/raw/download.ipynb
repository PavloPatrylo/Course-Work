# %%
import tarfile

archive_path = r"D:\python VS\Course Work\flood_climate_coursework\data\raw\rastr.tar.gz"
extract_to = r"D:\python VS\Course Work\flood_climate_coursework\data\raw"

with tarfile.open(archive_path, "r:gz") as tar:
    tar.extractall(path=extract_to)

print("Готово.")
# Out:
# Готово.
